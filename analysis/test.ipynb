# %%
from mouse_track_viewer import visualize_mouse_track

# %%
fig = visualize_mouse_track(
    results_db_path="../HMR_project.results.sqlite",
    project_db_path="../HMR_project.sqlite",
    assignment_id=801,
    output_path="track_42.png",  # optional; saves at 150 dpi
    show=False,  # set True in a notebook
)
