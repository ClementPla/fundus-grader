# %%
from mouse_track_viewer import visualize_mouse_track

# %%
fig = visualize_mouse_track(
    results_db_path="../HMR.results.sqlite",
    project_db_path="../HMR.sqlite",
    assignment_id=401,
    output_path="track_201.png",  # optional; saves at 150 dpi
    show=False,  # set True in a notebook
)
